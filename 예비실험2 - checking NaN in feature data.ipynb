# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df_feature = pd.read_csv("../예비2 - 변수선택용 proact 데이터/p2_features_combined_with_nans.csv")
df_target = pd.read_csv("../예비2 - 변수선택용 proact 데이터/p2_ALSFRS_slope(target).csv")

# %%
df_feature.head()
# Out:
#    Unnamed: 0  SubjectID   Age Gender     Race family_ALS_hist  diag_delta  \
# 0           0        329  38.0      F    Black             NaN     -1068.0
# 1           1        533  65.0      F    White             NaN       -44.0
# 2           2        649  48.0      F    White             NaN         NaN
# 3           3        708  46.0      M    White             NaN      -986.0
# 4           4        902  77.0      F  Unknown             NaN       -49.0
#
#    onset_delta onset_site if_use_Riluzole  ... bp_d_slope  bp_s_slope  \
# 0      -1706.0       Limb             NaN  ...        NaN         NaN
# 1      -1023.0     Bulbar             NaN  ...   0.021978   -0.043956
# 2          NaN        NaN             Yes  ...   0.000000    0.000000
# 3      -1070.0     Bulbar             NaN  ...        NaN         NaN
# 4       -514.0       Limb             Yes  ...   0.000000   -0.164835
#
#    pulse_slope  resp_rate_slope  temp_slope  mean_weight  max_weight  \
# 0          NaN        -0.138889   -0.001389    50.380000        52.2
# 1     0.109890         0.000000   -0.003297    51.000000        52.0
# 2     0.196721         0.016393         NaN    74.566667        75.6
# 3          NaN         0.021978   -0.012088    60.450000        63.8
# 4    -0.087912         0.043956    0.003297    62.220000        63.5
#
#    min_weight  slope_weight  mean_BMI
# 0        45.8     -0.088889       NaN
# 1        50.5     -0.005495       NaN
# 2        73.7      0.011475   0.00299
# 3        53.9     -0.108791       NaN
# 4        61.7     -0.019780   0.00239
#
# [5 rows x 48 columns]

# %%
print("Our df has a total of {} null values".format(df_feature.isnull().sum().sum()))
print()
# Out:
# Our df has a total of 208682 null values

# %%
def report_nulls(df):
    '''
    Show a fast report of the DF.
    '''
    rows = df.shape[0]
    columns = df.shape[1]
    null_cols = 0
    list_of_nulls_cols = []
    list_of_nulls_cols_pcn = []
    list_of_nulls_cols_over60 = []
    for col in list(df.columns):
        null_values_rows = df[col].isnull().sum()
        null_rows_pcn = round(((null_values_rows)/rows)*100, 2)
        col_type = df[col].dtype
        if null_values_rows > 0:
            print("The column {} has {} null values. It is {}% of total rows.".format(col, null_values_rows, null_rows_pcn))
            print("The column {} is of type {}.\n".format(col, col_type))
            null_cols += 1
            list_of_nulls_cols.append(col)
            list_of_nulls_cols_pcn.append(null_rows_pcn)
            if null_rows_pcn > 60:
                list_of_nulls_cols_over60.append(col)
    null_cols_pcn = round((null_cols/columns)*100, 2)
    print("The DataFrame has {} columns with null values. It is {}% of total columns.".format(null_cols, null_cols_pcn))
    plt.plot(list_of_nulls_cols, list_of_nulls_cols_pcn)
    return list_of_nulls_cols_over60

report_nulls(df_feature)
# Out:
# The column Age has 2070 null values. It is 23.43% of total rows.
# The column Age is of type float64.
#
# The column Gender has 2070 null values. It is 23.43% of total rows.
# The column Gender is of type object.
#
# The column Race has 2070 null values. It is 23.43% of total rows.
# The column Race is of type object.
#
# The column family_ALS_hist has 8248 null values. It is 93.36% of total rows.
# The column family_ALS_hist is of type object.
#
# The column diag_delta has 5906 null values. It is 66.85% of total rows.
# The column diag_delta is of type float64.
#
# The column onset_delta has 5906 null values. It is 66.85% of total rows.
# The column onset_delta is of type float64.
#
# The column onset_site has 5907 null values. It is 66.86% of total rows.
# The column onset_site is of type object.
#
# The column if_use_Riluzole has 1569 null values. It is 17.76% of total rows.
# The column if_use_Riluzole is of type object.
#
# The column treatment_group has 852 null values. It is 9.64% of total rows.
# The column treatment_group is of type object.
#
# The column alsfrs_total_slope has 3960 null values. It is 44.82% of total rows.
# The column alsfrs_total_slope is of type float64.
#
# The column mean_alsfrs_total has 3839 null values. It is 43.45% of total rows.
# The column mean_alsfrs_total is of type float64.
#
# The column min_alsfrs_total has 3839 null values. It is 43.45% of total rows.
# The column min_alsfrs_total is of type float64.
#
# The column max_alsfrs_total has 3839 null values. It is 43.45% of total rows.
# The column max_alsfrs_total is of type float64.
#
# The column fvc_slope has 4248 null values. It is 48.08% of total rows.
# The column fvc_slope is of type float64.
#
# The column fvc_mean has 2554 null values. It is 28.91% of total rows.
# The column fvc_mean is of type float64.
#
# The column fvc_min has 2554 null values. It is 28.91% of total rows.
# The column fvc_min is of type float64.
#
# The column fvc_max has 2554 null values. It is 28.91% of total rows.
# The column fvc_max is of type float64.
#
# The column svc_slope has 8560 null values. It is 96.89% of total rows.
# The column svc_slope is of type float64.
#
# The column svc_mean has 8560 null values. It is 96.89% of total rows.
# The column svc_mean is of type float64.
#
# The column svc_min has 8560 null values. It is 96.89% of total rows.
# The column svc_min is of type float64.
#
# The column svc_max has 8560 null values. It is 96.89% of total rows.
# The column svc_max is of type float64.
#
# The column mean_bp_d has 4047 null values. It is 45.81% of total rows.
# The column mean_bp_d is of type float64.
#
# The column max_bp_d has 4047 null values. It is 45.81% of total rows.
# The column max_bp_d is of type float64.
#
# The column min_bp_d has 4047 null values. It is 45.81% of total rows.
# The column min_bp_d is of type float64.
#
# The column mean_bp_s has 4047 null values. It is 45.81% of total rows.
# The column mean_bp_s is of type float64.
#
# The column max_bp_s has 4047 null values. It is 45.81% of total rows.
# The column max_bp_s is of type float64.
#
# The column min_bp_s has 4047 null values. It is 45.81% of total rows.
# The column min_bp_s is of type float64.
#
# The column mean_pulse has 4052 null values. It is 45.86% of total rows.
# The column mean_pulse is of type float64.
#
# The column max_pulse has 4052 null values. It is 45.86% of total rows.
# The column max_pulse is of type float64.
#
# The column min_pulse has 4052 null values. It is 45.86% of total rows.
# The column min_pulse is of type float64.
#
# The column mean_resp_rate has 4504 null values. It is 50.98% of total rows.
# The column mean_resp_rate is of type float64.
#
# The column max_resp_rate has 4504 null values. It is 50.98% of total rows.
# The column max_resp_rate is of type float64.
#
# The column min_resp_rate has 4504 null values. It is 50.98% of total rows.
# The column min_resp_rate is of type float64.
#
# The column mean_temp has 6731 null values. It is 76.19% of total rows.
# The column mean_temp is of type float64.
#
# The column max_temp has 6731 null values. It is 76.19% of total rows.
# The column max_temp is of type float64.
#
# The column min_temp has 6731 null values. It is 76.19% of total rows.
# The column min_temp is of type float64.
#
# The column bp_d_slope has 4234 null values. It is 47.92% of total rows.
# The column bp_d_slope is of type float64.
#
# The column bp_s_slope has 4234 null values. It is 47.92% of total rows.
# The column bp_s_slope is of type float64.
#
# The column pulse_slope has 4236 null values. It is 47.95% of total rows.
# The column pulse_slope is of type float64.
#
# The column resp_rate_slope has 4602 null values. It is 52.09% of total rows.
# The column resp_rate_slope is of type float64.
#
# The column temp_slope has 6784 null values. It is 76.79% of total rows.
# The column temp_slope is of type float64.
#
# The column mean_weight has 2770 null values. It is 31.35% of total rows.
# The column mean_weight is of type float64.
#
# The column max_weight has 2770 null values. It is 31.35% of total rows.
# The column max_weight is of type float64.
#
# The column min_weight has 2770 null values. It is 31.35% of total rows.
# The column min_weight is of type float64.
#
# The column slope_weight has 4416 null values. It is 49.98% of total rows.
# The column slope_weight is of type float64.
#
# The column mean_BMI has 5498 null values. It is 62.23% of total rows.
# The column mean_BMI is of type float64.
#
# The DataFrame has 46 columns with null values. It is 95.83% of total columns.
# ['family_ALS_hist',
#  'diag_delta',
#  'onset_delta',
#  'onset_site',
#  'svc_slope',
#  'svc_mean',
#  'svc_min',
#  'svc_max',
#  'mean_temp',
#  'max_temp',
#  'min_temp',
#  'temp_slope',
#  'mean_BMI']

# %%
extent = list(df_target["SubjectID"].unique())
df_feature.query("SubjectID == {0}".format(extent), inplace=True)

# %%
df_feature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2281 entries, 1 to 6760
# Data columns (total 48 columns):
# Unnamed: 0            2281 non-null int64
# SubjectID             2281 non-null int64
# Age                   2281 non-null float64
# Gender                2281 non-null object
# Race                  2281 non-null object
# family_ALS_hist       380 non-null object
# diag_delta            876 non-null float64
# onset_delta           876 non-null float64
# onset_site            876 non-null object
# if_use_Riluzole       1982 non-null object
# treatment_group       2095 non-null object
# alsfrs_total_slope    2279 non-null float64
# mean_alsfrs_total     2281 non-null float64
# min_alsfrs_total      2281 non-null float64
# max_alsfrs_total      2281 non-null float64
# fvc_slope             2064 non-null float64
# fvc_mean              2081 non-null float64
# fvc_min               2081 non-null float64
# fvc_max               2081 non-null float64
# svc_slope             198 non-null float64
# svc_mean              198 non-null float64
# svc_min               198 non-null float64
# svc_max               198 non-null float64
# mean_bp_d             2086 non-null float64
# max_bp_d              2086 non-null float64
# min_bp_d              2086 non-null float64
# mean_bp_s             2086 non-null float64
# max_bp_s              2086 non-null float64
# min_bp_s              2086 non-null float64
# mean_pulse            2086 non-null float64
# max_pulse             2086 non-null float64
# min_pulse             2086 non-null float64
# mean_resp_rate        1924 non-null float64
# max_resp_rate         1924 non-null float64
# min_resp_rate         1924 non-null float64
# mean_temp             524 non-null float64
# max_temp              524 non-null float64
# min_temp              524 non-null float64
# bp_d_slope            2086 non-null float64
# bp_s_slope            2086 non-null float64
# pulse_slope           2086 non-null float64
# resp_rate_slope       1924 non-null float64
# temp_slope            524 non-null float64
# mean_weight           2261 non-null float64
# max_weight            2261 non-null float64
# min_weight            2261 non-null float64
# slope_weight          2080 non-null float64
# mean_BMI              1338 non-null float64
# dtypes: float64(40), int64(2), object(6)
# memory usage: 873.2+ KB

# %%
def report_nulls(df):
    '''
    Show a fast report of the DF.
    '''
    rows = df.shape[0]
    columns = df.shape[1]
    null_cols = 0
    list_of_nulls_cols = []
    list_of_nulls_cols_pcn = []
    list_of_nulls_cols_over60 = []
    for col in list(df.columns):
        null_values_rows = df[col].isnull().sum()
        null_rows_pcn = round(((null_values_rows)/rows)*100, 2)
        col_type = df[col].dtype
        if null_values_rows > 0:
            print("The column {} has {} null values. It is {}% of total rows.".format(col, null_values_rows, null_rows_pcn))
            print("The column {} is of type {}.\n".format(col, col_type))
            null_cols += 1
            list_of_nulls_cols.append(col)
            list_of_nulls_cols_pcn.append(null_rows_pcn)
            if null_rows_pcn > 60:
                list_of_nulls_cols_over60.append(col)
    null_cols_pcn = round((null_cols/columns)*100, 2)
    print("The DataFrame has {} columns with null values. It is {}% of total columns.".format(null_cols, null_cols_pcn))
    plt.plot(list_of_nulls_cols, list_of_nulls_cols_pcn)
    return list_of_nulls_cols_over60

report_nulls(df_feature)
# Out:
# The column family_ALS_hist has 1901 null values. It is 83.34% of total rows.
# The column family_ALS_hist is of type object.
#
# The column diag_delta has 1405 null values. It is 61.6% of total rows.
# The column diag_delta is of type float64.
#
# The column onset_delta has 1405 null values. It is 61.6% of total rows.
# The column onset_delta is of type float64.
#
# The column onset_site has 1405 null values. It is 61.6% of total rows.
# The column onset_site is of type object.
#
# The column if_use_Riluzole has 299 null values. It is 13.11% of total rows.
# The column if_use_Riluzole is of type object.
#
# The column treatment_group has 186 null values. It is 8.15% of total rows.
# The column treatment_group is of type object.
#
# The column alsfrs_total_slope has 2 null values. It is 0.09% of total rows.
# The column alsfrs_total_slope is of type float64.
#
# The column fvc_slope has 217 null values. It is 9.51% of total rows.
# The column fvc_slope is of type float64.
#
# The column fvc_mean has 200 null values. It is 8.77% of total rows.
# The column fvc_mean is of type float64.
#
# The column fvc_min has 200 null values. It is 8.77% of total rows.
# The column fvc_min is of type float64.
#
# The column fvc_max has 200 null values. It is 8.77% of total rows.
# The column fvc_max is of type float64.
#
# The column svc_slope has 2083 null values. It is 91.32% of total rows.
# The column svc_slope is of type float64.
#
# The column svc_mean has 2083 null values. It is 91.32% of total rows.
# The column svc_mean is of type float64.
#
# The column svc_min has 2083 null values. It is 91.32% of total rows.
# The column svc_min is of type float64.
#
# The column svc_max has 2083 null values. It is 91.32% of total rows.
# The column svc_max is of type float64.
#
# The column mean_bp_d has 195 null values. It is 8.55% of total rows.
# The column mean_bp_d is of type float64.
#
# The column max_bp_d has 195 null values. It is 8.55% of total rows.
# The column max_bp_d is of type float64.
#
# The column min_bp_d has 195 null values. It is 8.55% of total rows.
# The column min_bp_d is of type float64.
#
# The column mean_bp_s has 195 null values. It is 8.55% of total rows.
# The column mean_bp_s is of type float64.
#
# The column max_bp_s has 195 null values. It is 8.55% of total rows.
# The column max_bp_s is of type float64.
#
# The column min_bp_s has 195 null values. It is 8.55% of total rows.
# The column min_bp_s is of type float64.
#
# The column mean_pulse has 195 null values. It is 8.55% of total rows.
# The column mean_pulse is of type float64.
#
# The column max_pulse has 195 null values. It is 8.55% of total rows.
# The column max_pulse is of type float64.
#
# The column min_pulse has 195 null values. It is 8.55% of total rows.
# The column min_pulse is of type float64.
#
# The column mean_resp_rate has 357 null values. It is 15.65% of total rows.
# The column mean_resp_rate is of type float64.
#
# The column max_resp_rate has 357 null values. It is 15.65% of total rows.
# The column max_resp_rate is of type float64.
#
# The column min_resp_rate has 357 null values. It is 15.65% of total rows.
# The column min_resp_rate is of type float64.
#
# The column mean_temp has 1757 null values. It is 77.03% of total rows.
# The column mean_temp is of type float64.
#
# The column max_temp has 1757 null values. It is 77.03% of total rows.
# The column max_temp is of type float64.
#
# The column min_temp has 1757 null values. It is 77.03% of total rows.
# The column min_temp is of type float64.
#
# The column bp_d_slope has 195 null values. It is 8.55% of total rows.
# The column bp_d_slope is of type float64.
#
# The column bp_s_slope has 195 null values. It is 8.55% of total rows.
# The column bp_s_slope is of type float64.
#
# The column pulse_slope has 195 null values. It is 8.55% of total rows.
# The column pulse_slope is of type float64.
#
# The column resp_rate_slope has 357 null values. It is 15.65% of total rows.
# The column resp_rate_slope is of type float64.
#
# The column temp_slope has 1757 null values. It is 77.03% of total rows.
# The column temp_slope is of type float64.
#
# The column mean_weight has 20 null values. It is 0.88% of total rows.
# The column mean_weight is of type float64.
#
# The column max_weight has 20 null values. It is 0.88% of total rows.
# The column max_weight is of type float64.
#
# The column min_weight has 20 null values. It is 0.88% of total rows.
# The column min_weight is of type float64.
#
# The column slope_weight has 201 null values. It is 8.81% of total rows.
# The column slope_weight is of type float64.
#
# The column mean_BMI has 943 null values. It is 41.34% of total rows.
# The column mean_BMI is of type float64.
#
# The DataFrame has 40 columns with null values. It is 83.33% of total columns.
# ['family_ALS_hist',
#  'diag_delta',
#  'onset_delta',
#  'onset_site',
#  'svc_slope',
#  'svc_mean',
#  'svc_min',
#  'svc_max',
#  'mean_temp',
#  'max_temp',
#  'min_temp',
#  'temp_slope']
